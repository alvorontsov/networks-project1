# %%
import pandas as pd
import numpy as np
import requests
import urllib2, json, sys
import matplotlib.pyplot as plt
# %matplotlib inline
# coding=utf-8

# %%
import networkx as nx
import codecs
UTF8Writer = codecs.getwriter('utf8')
sys.stdout = UTF8Writer(sys.stdout)

# %%
VK_API_TOKEN = 'My token was here'
VK_USER_ID = 182824801
#url  = u'https://api.vk.com/method/friends.get?fields=sex,city,education&uid=%s&lang=en&version=5.73&access_token=%s' %(VK_USER_ID ,VK_API_TOKEN)
#res  = urllib2.urlopen(url).read()
#data = json.loads( res )

# %%
def get_friends(user_id):
    url  = u'https://api.vk.com/method/friends.get?fields=sex,city,education&uid=%s&lang=en&version=5.73&access_token=%s' %(user_id ,VK_API_TOKEN)
    res  = urllib2.urlopen(url).read()
    data = json.loads( res )
    return pd.io.json.json_normalize(data['response'])

# %% [markdown]
# Let's construct a nice pandas dataframe from our JSON

# %%
df = get_friends(VK_USER_ID)
df.insert(0, 'is_friend_of', VK_USER_ID)

# %%
df.head()
# Out:
#    is_friend_of  city deactivated education_form      education_status  \
# 0     182824801   NaN      banned            NaN                   NaN
# 1     182824801   0.0         NaN      Full-time   Alumna (Bachelor's)
# 2     182824801   1.0         NaN            NaN                   NaN
# 3     182824801   1.0         NaN      Full-time  Student (Bachelor's)
# 4     182824801   0.0         NaN      Full-time                   NaN
#
#    faculty                                       faculty_name first_name  \
# 0      NaN                                                NaN        Mrs
# 1    475.0  Факультет социальных наук (Государственного и ...       Adel
# 2      NaN                                                NaN     Kirill
# 3    474.0  Факультет бизнеса и менеджмента (Бизнес-информ...      Anton
# 4   1484.0        Факультет геологии и геофизики нефти и газа      Sonya
#
#    graduation last_name  online  sex      uid  university  \
# 0         NaN     Smith       0    1    16450         NaN
# 1      2008.0  Shadrina       0    1    42727       128.0
# 2         NaN  Gomenyuk       0    2    50385         NaN
# 3      2016.0  Piskunov       0    2  4411633       128.0
# 4         0.0  Gogoleva       1    1  4793267       334.0
#
#                             university_name  user_id
# 0                                       NaN    16450
# 1                          НИУ ВШЭ (ГУ-ВШЭ)    42727
# 2                                       NaN    50385
# 3                          НИУ ВШЭ (ГУ-ВШЭ)  4411633
# 4  РГУ нефти и газа (НИУ) им. И. М. Губкина  4793267

# %%
import time
frames = [df]
# Let's get all friends for each our friend
i = 1
for item in df.uid:
    print'iteration', i
    i = i + 1
    print'friend uid', item
    try:
        new_df = get_friends(item)
        new_df.insert(0, 'is_friend_of', item)
        frames.append(new_df)
        # print the number of friends just to be sure that we are not banned on this step
        print'new request len', len(new_df)
        # VK API has a query limit - 3 queries per second, so, we better wait for 0.4 seconds after each query to be sure not to get banned
        time.sleep(0.4)
    except:
        # sometimes we can get an error if the user is banned, or if we are banned
        print('error')
# Out:
# iteration 1
# friend uid 16450
# error
# iteration 2
# friend uid 42727
# new request len 2511
# iteration 3
# friend uid 50385
# new request len 367
# iteration 4
# friend uid 4411633
# new request len 744
# iteration 5
# friend uid 4793267
# new request len 198
# iteration 131
# friend uid 116176693
# new request len 101
# iteration 132
# friend uid 123175896
# new request len 192
# iteration 133
# friend uid 125145242
# new request len 199
# iteration 134
# friend uid 135542462
# new request len 115
# iteration 135
# friend uid 136744597
# new request len 1335
# iteration 136
# friend uid 136778205
# new request len 176
# iteration 137
# friend uid 138139288
# new request len 529
# iteration 138
# friend uid 139552081
# new request len 298
# iteration 139
# friend uid 140217109
# new request len 163
# iteration 140
# friend uid 140680040
# new request len 326
# iteration 141
# friend uid 145708429
# new request len 126
# iteration 142
# friend uid 146108531
# new request len 1549
# iteration 143
# friend uid 152122717
# new request len 415
# iteration 144
# friend uid 157188286
# new request len 525
# iteration 145
# friend uid 166445045
# new request len 284
# iteration 146
# friend uid 178760847
# new request len 113
# iteration 147
# friend uid 182794807
# new request len 345
# iteration 148
# friend uid 183614829
# new request len 132
# iteration 149
# friend uid 215563351
# new request len 206
# iteration 150
# friend uid 219696400
# new request len 97
# iteration 151
# friend uid 292338302
# new request len 176
# iteration 152
# friend uid 354139402
# new request len 44
# iteration 153
# friend uid 404777238
# new request len 250

# %% [markdown]
# Now, let's remove banned users and self from our dataframe

# %%
#merge all our data
result = pd.concat(frames)

# %%
len(result)
# Out:
# 59680

# %% [markdown]
# We have length of 59680. Let's save our data to csv to not to deal with VK API again

# %%
result.to_csv('data.csv', encoding='utf8')

# %%
result
# Out:
#        city deactivated education_form      education_status    faculty  \
# 0       NaN      banned            NaN                   NaN        NaN
# 1       0.0         NaN      Full-time   Alumna (Bachelor's)      475.0
# 2       1.0         NaN            NaN                   NaN        NaN
# 3       1.0         NaN      Full-time  Student (Bachelor's)      474.0
# 4       0.0         NaN      Full-time                   NaN     1484.0
# 5       1.0         NaN            NaN                   NaN        NaN
# 6       0.0         NaN            NaN                   NaN        0.0
# 7       1.0         NaN      Full-time  Student (Bachelor's)      484.0
# 8      61.0         NaN      Full-time   Alumna (Specialist)     2704.0
# 9       1.0         NaN            NaN                   NaN        NaN
# 10      1.0         NaN      Full-time  Alumnus (Bachelor's)    49264.0
# 11      1.0         NaN            NaN   Alumna (Bachelor's)      476.0
# 12      1.0         NaN            NaN                   NaN     2302.0
# 13      0.0         NaN            NaN  Student (Bachelor's)      474.0
# 14      1.0         NaN            NaN                   NaN        NaN
# 15      1.0         NaN      Full-time  Student (Bachelor's)      484.0
# 16   1463.0         NaN      Full-time  Student (Bachelor's)     1033.0
# 17      1.0         NaN            NaN                   NaN        NaN
# 18      1.0         NaN      Full-time  Student (Bachelor's)      475.0
# 19     61.0         NaN            NaN  Student (Specialist)    29152.0
# 20      1.0         NaN            NaN  Student (Bachelor's)      474.0
# 21      0.0         NaN      Full-time                   PhD  2166855.0
# 22   1463.0         NaN      Full-time  Student (Specialist)      849.0
# 23      1.0         NaN            NaN                   NaN        NaN
# 24    117.0         NaN            NaN                   NaN        NaN
# 25      1.0         NaN            NaN                   NaN      474.0
# 26      1.0         NaN            NaN                   NaN        0.0
# 27      1.0         NaN            NaN                   NaN        NaN
# 28      1.0         NaN            NaN  Alumnus (Bachelor's)      474.0
# 29      1.0         NaN      Full-time  Student (Bachelor's)  2145570.0
# ..      ...         ...            ...                   ...        ...
# 220     1.0         NaN            NaN                   NaN        NaN
# 221     1.0         NaN            NaN                   NaN        NaN
# 222    19.0         NaN            NaN                   NaN        NaN
# 223     0.0         NaN            NaN                   NaN        NaN
# 224    10.0         NaN            NaN                   NaN        0.0
# 225     1.0         NaN            NaN                   NaN        0.0
# 226  1469.0         NaN            NaN                   NaN        0.0
# 227     1.0         NaN            NaN                   NaN      906.0
# 228     1.0         NaN            NaN                   NaN        NaN
# 229     1.0         NaN            NaN                   NaN        NaN
# 230     1.0         NaN            NaN                   NaN        0.0
# 231     1.0         NaN            NaN                   NaN        NaN
# 232     1.0         NaN            NaN                   NaN        NaN
# 233     1.0         NaN            NaN                   NaN        0.0
# 234     1.0         NaN            NaN                   NaN        0.0
# 235     1.0         NaN            NaN                   NaN      458.0
# 236     1.0         NaN            NaN                   NaN        NaN
# 237     1.0         NaN            NaN                   NaN        NaN
# 238    68.0         NaN            NaN                   NaN        NaN
# 239     1.0         NaN            NaN                   NaN        0.0
# 240     0.0         NaN            NaN                   NaN        0.0
# 241     0.0         NaN            NaN                   NaN        NaN
# 242    40.0         NaN            NaN                   NaN        NaN
# 243     1.0         NaN            NaN                   NaN        0.0
# 244     1.0         NaN            NaN                   NaN        0.0
# 245     1.0         NaN            NaN                   NaN        0.0
# 246     0.0         NaN            NaN                   NaN        0.0
# 247     NaN     deleted            NaN                   NaN        NaN
# 248     0.0         NaN            NaN                   NaN        0.0
# 249     1.0         NaN            NaN                   NaN        NaN
#
#                                           faculty_name      first_name  \
# 0                                                  NaN             Mrs
# 1    Факультет социальных наук (Государственного и ...            Adel
# 2                                                  NaN          Kirill
# 3    Факультет бизнеса и менеджмента (Бизнес-информ...           Anton
# 4          Факультет геологии и геофизики нефти и газа           Sonya
# 5                                                  NaN          Daniil
# 6                                                                Dasha
# 7                         Факультет экономических наук           Katya
# 8                     Институт экономики и менеджмента           Yulya
# 9                                                  NaN       Alexandra
# 10        Факультет физической и квантовой электроники          Alexey
# 11             Факультет коммуникаций, медиа и дизайна           Maria
# 12   Факультет гуманитарных наук (Философии, Филоло...           Maria
# 13   Факультет бизнеса и менеджмента (Бизнес-информ...           Sasha
# 14                                                 NaN          Semyon
# 15                        Факультет экономических наук            Olya
# 16           Факультет информатики и систем управления         Grigory
# 17                                                 NaN       Vladislav
# 18   Факультет социальных наук (Государственного и ...           Roman
# 19                                Юридический институт           Elena
# 20   Факультет бизнеса и менеджмента (Бизнес-информ...             Ann
# 21                         Факультет компьютерных наук           Serzh
# 22                                  Лечебный факультет           Anton
# 23                                                 NaN            Vika
# 24                                                 NaN        Vladimir
# 25   Факультет бизнеса и менеджмента (Бизнес-информ...        Bakhtiar
# 26                                                               Danil
# 27                                                 NaN           Maria
# 28   Факультет бизнеса и менеджмента (Бизнес-информ...           Bulat
# 29   Факультет геоэкологии и географии (бывш. Эколо...            Ilya
# ..                                                 ...             ...
# 220                                                NaN           Darya
# 221                                                NaN          Dmitry
# 222                                                NaN           Tiana
# 223                                                NaN          Ksenia
# 224                                                          Svetoslav
# 225                                                               Roxy
# 226                                                               Emil
# 227                            Экономический факультет            Anna
# 228                                                NaN           Artur
# 229                                                NaN        Svetlana
# 230                                                           Nadezhda
# 231                                                NaN           Denis
# 232                                                NaN          Ksenia
# 233                                                              Irina
# 234                                                          Stanislav
# 235                   Мировой музыкальной культуры\r\n        Yaroslav
# 236                                                NaN         Looking
# 237                                                NaN           Darya
# 238                                                NaN         Laarika
# 239                                                           Angelina
# 240                                                     Timondr-Toshan
# 241                                                NaN       Ekaterina
# 242                                                NaN       Ekaterina
# 243                                                             Ushnoy
# 244                                                              Alisa
# 245                                                           Angelika
# 246                                                              Maria
# 247                                                NaN           Alisa
# 248                                                            Natalya
# 249                                                NaN           Alisa
#
#      graduation  is_friend_of            last_name lists  online  sex  \
# 0           NaN     182824801                Smith   NaN       0    1
# 1        2008.0     182824801             Shadrina   NaN       0    1
# 2           NaN     182824801             Gomenyuk   NaN       0    2
# 3        2016.0     182824801             Piskunov   NaN       0    2
# 4           0.0     182824801             Gogoleva   NaN       1    1
# 5           NaN     182824801              Korolev   NaN       0    2
# 6           0.0     182824801             Andreeva   NaN       0    1
# 7           0.0     182824801              Kolfild   NaN       0    1
# 8        2008.0     182824801             Bulatova   NaN       0    1
# 9           NaN     182824801               Popova   NaN       0    1
# 10       2017.0     182824801         Khudorozhkov   NaN       0    2
# 11       2016.0     182824801               Sanina   NaN       0    1
# 12       2017.0     182824801             Shifrina   NaN       0    1
# 13       2018.0     182824801           Ignashkina   NaN       1    1
# 14          NaN     182824801             Pribylov   NaN       0    2
# 15       2017.0     182824801             Kazhaeva   NaN       0    1
# 16       2018.0     182824801                Lukin   NaN       1    2
# 17          NaN     182824801              Budruev   NaN       0    2
# 18       2013.0     182824801            Sidorchuk   NaN       0    2
# 19       2015.0     182824801              Fadeeva   NaN       0    1
# 20       2017.0     182824801          Kolesnikova   NaN       0    1
# 21       2018.0     182824801               Suslov   NaN       0    2
# 22          0.0     182824801           Chernyshev   NaN       0    2
# 23          NaN     182824801           Akhromkina   NaN       0    1
# 24          NaN     182824801             Ischenko   NaN       0    2
# 25          0.0     182824801             Beysenov   NaN       0    2
# 26          0.0     182824801              Rakshas   NaN       0    2
# 27          NaN     182824801            Kachalova   NaN       0    1
# 28       2017.0     182824801             Sufyanov   NaN       1    2
# 29       2018.0     182824801            Terentyev   NaN       0    2
# ..          ...           ...                  ...   ...     ...  ...
# 220         NaN     404777238              Pankova   NaN       0    1
# 221         NaN     404777238              Stulnev   NaN       0    2
# 222         NaN     404777238             Shpakova   NaN       1    1
# 223         NaN     404777238            Alexeevna   NaN       0    1
# 224         0.0     404777238             Chobotok   NaN       0    2
# 225         0.0     404777238                 Will   NaN       0    1
# 226         0.0     404777238                 Gart   NaN       0    2
# 227         0.0     404777238           Bulychyova   NaN       0    1
# 228         NaN     404777238          Matroshilov   NaN       0    2
# 229         NaN     404777238             Pavlovna   NaN       0    1
# 230         0.0     404777238            Zakharova   NaN       0    1
# 231         NaN     404777238             Melnikov   NaN       0    2
# 232         NaN     404777238                  Esh   NaN       0    1
# 233         0.0     404777238           Runushkina   NaN       0    1
# 234         0.0     404777238              Polekha   NaN       0    2
# 235         0.0     404777238              Gordeev   NaN       1    2
# 236         NaN     404777238                Dream   NaN       0    2
# 237         NaN     404777238          Pavlovskaya   NaN       0    1
# 238         NaN     404777238           Zelentsova   NaN       0    1
# 239         0.0     404777238           Bondarenko   NaN       0    1
# 240         0.0     404777238            Politayko   NaN       0    1
# 241         NaN     404777238            Ekaterina   NaN       0    1
# 242         NaN     404777238          Gennadyevna   NaN       1    1
# 243         0.0     404777238           Monitoring   NaN       0    2
# 244         0.0     404777238                 Lass   NaN       0    1
# 245         0.0     404777238                 Nyan   NaN       0    1
# 246         0.0     404777238              Zubkova   NaN       0    1
# 247         NaN     404777238                 Kort   NaN       0    1
# 248         0.0     404777238  Galupa-Schebelskaya   NaN       0    1
# 249         NaN     404777238                 Kort   NaN       0    1
#
#            uid  university                                    university_name  \
# 0        16450         NaN                                                NaN
# 1        42727       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 2        50385         NaN                                                NaN
# 3      4411633       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 4      4793267       334.0           РГУ нефти и газа (НИУ) им. И. М. Губкина
# 5      5417191         NaN                                                NaN
# 6      6093731         0.0
# 7      6388013       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 8      6537447       541.0                БФУ им. Канта (бывш. РГУ им. Канта)
# 9      6633765         NaN                                                NaN
# 10     6805396       297.0                                          МФТИ (ГУ)
# 11     6862930       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 12     7048636       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 13     7083123       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 14     7321434         NaN                                                NaN
# 15     7343298       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 16     7358127       250.0                             МГТУ им. Н. Э. Баумана
# 17     7422772         NaN                                                NaN
# 18     7623029       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 19     8038711       541.0                БФУ им. Канта (бывш. РГУ им. Канта)
# 20     8545045       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 21     8900083       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 22     8920879       215.0  Первый МГМУ им. И. М. Сеченова (Сеченовский Ун...
# 23     8954930         NaN                                                NaN
# 24     8964616         NaN                                                NaN
# 25    10105498       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 26    10304893         0.0
# 27    11397480         NaN                                                NaN
# 28    11496815       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 29    11776426       232.0                      РГГРУ (МГРИ) им. Орджоникидзе
# ..         ...         ...                                                ...
# 220  209789078         NaN                                                NaN
# 221  218913087         NaN                                                NaN
# 222  232108669         NaN                                                NaN
# 223  246904873         NaN                                                NaN
# 224  247314826         0.0
# 225  255919082         0.0
# 226  277729372         0.0
# 227  287104191       228.0                                               МАДИ
# 228  287820303         NaN                                                NaN
# 229  290473189         NaN                                                NaN
# 230  303204536         0.0
# 231  324405001         NaN                                                NaN
# 232  325893555         NaN                                                NaN
# 233  327631603       257.0                                 МГИК (бывш. МГУКИ)
# 234  331824098         0.0
# 235  332365381       124.0                          ГКА им. Маймонида (МГУДТ)
# 236  335998223         NaN                                                NaN
# 237  336809894         NaN                                                NaN
# 238  358130506         NaN                                                NaN
# 239  358974277         0.0
# 240  401593236         0.0
# 241  423507993         NaN                                                NaN
# 242  428566038         NaN                                                NaN
# 243  434548699         0.0
# 244  441654248         0.0
# 245  442676702         0.0
# 246  445737391         0.0
# 247  450200664         NaN                                                NaN
# 248  453650114         0.0
# 249  463921980         NaN                                                NaN
#
#        user_id
# 0        16450
# 1        42727
# 2        50385
# 3      4411633
# 4      4793267
# 5      5417191
# 6      6093731
# 7      6388013
# 8      6537447
# 9      6633765
# 10     6805396
# 11     6862930
# 12     7048636
# 13     7083123
# 14     7321434
# 15     7343298
# 16     7358127
# 17     7422772
# 18     7623029
# 19     8038711
# 20     8545045
# 21     8900083
# 22     8920879
# 23     8954930
# 24     8964616
# 25    10105498
# 26    10304893
# 27    11397480
# 28    11496815
# 29    11776426
# ..         ...
# 220  209789078
# 221  218913087
# 222  232108669
# 223  246904873
# 224  247314826
# 225  255919082
# 226  277729372
# 227  287104191
# 228  287820303
# 229  290473189
# 230  303204536
# 231  324405001
# 232  325893555
# 233  327631603
# 234  331824098
# 235  332365381
# 236  335998223
# 237  336809894
# 238  358130506
# 239  358974277
# 240  401593236
# 241  423507993
# 242  428566038
# 243  434548699
# 244  441654248
# 245  442676702
# 246  445737391
# 247  450200664
# 248  453650114
# 249  463921980
#
# [59680 rows x 17 columns]

# %%
data = pd.read_csv('data.csv')

# %%
data.loc[1000:1050]
# Out:
#       Unnamed: 0    city deactivated education_form      education_status  \
# 1000         847     1.0         NaN            NaN                   NaN
# 1001         848   859.0         NaN            NaN                   NaN
# 1002         849     1.0         NaN            NaN                   NaN
# 1003         850     1.0         NaN      Full-time                   NaN
# 1004         851   157.0         NaN            NaN                   NaN
# 1005         852     NaN     deleted            NaN                   NaN
# 1006         853     2.0         NaN            NaN                   NaN
# 1007         854     1.0         NaN            NaN                   NaN
# 1008         855   151.0         NaN            NaN                   NaN
# 1009         856     1.0         NaN      Full-time    Alumnus (Master's)
# 1010         857     1.0         NaN            NaN                   NaN
# 1011         858     1.0         NaN            NaN                   NaN
# 1012         859     NaN     deleted            NaN                   NaN
# 1013         860   459.0         NaN            NaN                   NaN
# 1038  2201111       671.0                                                НГУ
# 1039  2203390         NaN                                                NaN
# 1040  2208885         NaN                                                NaN
# 1041  2209696         2.0                                                МГУ
# 1042  2210634         NaN                                                NaN
# 1043  2212962         NaN                                                NaN
# 1044  2220543         NaN                                                NaN
# 1045  2224210       128.0                                   НИУ ВШЭ (ГУ-ВШЭ)
# 1046  2224272       111.0                                               ВГИК
# 1047  2238040         NaN                                                NaN
# 1048  2239630         NaN                                                NaN
# 1049  2241895         NaN                                                NaN
# 1050  2247925         NaN                                                NaN
#
#       user_id
# 1000  2039524
# 1001  2042305
# 1002  2042988
# 1003  2044752
# 1004  2058348
# 1005  2063374
# 1006  2067951
# 1007  2069582
# 1008  2072964
# 1009  2076289
# 1010  2076944
# 1011  2088444
# 1012  2096959
# 1013  2101737
# 1014  2107136
# 1015  2110030
# 1016  2111799
# 1017  2121426
# 1018  2123709
# 1019  2123842
# 1020  2124014
# 1021  2127586
# 1022  2144209
# 1023  2146045
# 1024  2147479
# 1025  2151694
# 1026  2156373
# 1027  2159411
# 1028  2159588
# 1029  2163194
# 1030  2167425
# 1031  2169389
# 1032  2170379
# 1033  2175849
# 1034  2177001
# 1035  2186215
# 1036  2188677
# 1037  2199366
# 1038  2201111
# 1039  2203390
# 1040  2208885
# 1041  2209696
# 1042  2210634
# 1043  2212962
# 1044  2220543
# 1045  2224210
# 1046  2224272
# 1047  2238040
# 1048  2239630
# 1049  2241895
# 1050  2247925

# %% [markdown]
# Now we surely saved our raw friends data to csv.

# %%
friends = data[data.is_friend_of == 14045314]
uids = list(friends.uid)

# %%
mutual = []
for item in my_friends:
    if item in uids:
        mutual.append(item)
        
mutual
# Out:
# [4793267,
#  6388013,
#  7343298,
#  8954930,
#  24676142,
#  30135950,
#  52217140,
#  55010019,
#  99232652,
#  157188286,
#  215563351]

# %%
# let's build a graph
np_df = data.as_matrix()
G = nx.Graph()
friends = []
names = {}
cities = {}
universities = {}
faculties = {}
for item in np_df:
    user_id = item[14] # user id
    if (user_id in my_friends):
        if not G.has_node(user_id):
            G.add_node(user_id)
            name = item[7] + ' ' + item[10] # get first name + last name
            names[user_id] = name
            cities[user_id] = item[1] # get city
            universities[user_id] = item[16] # get uni & faculty
            faculties[user_id] = item[6]
        from_id = item[9] # is friend of
        friends.append(user_id)
        if from_id != VK_USER_ID:
            G.add_edge(from_id, user_id)

# %%
universities
# Out:
# {16450: nan,
#  42727: '\xd0\x9d\xd0\x98\xd0\xa3 \xd0\x92\xd0\xa8\xd0\xad (\xd0\x93\xd0\xa3-\xd0\x92\xd0\xa8\xd0\xad)',
#  50385: nan,
#  4411633: '\xd0\x9d\xd0\x98\xd0\xa3 \xd0\x92\xd0\xa8\xd0\xad (\xd0\x93\xd0\xa3-\xd0\x92\xd0\xa8\xd0\xad)',
#  4793267: '\xd0\xa0\xd0\x93\xd0\xa3 \xd0\xbd\xd0\xb5\xd1\x84\xd1\x82\xd0\xb8 \xd0\xb8 \xd0\xb3\xd0\xb0\xd0\xb7\xd0\xb0 (\xd0\x9d\xd0\x98\xd0\xa3) \xd0\xb8\xd0\xbc. \xd0\x98. \xd0\x9c. \xd0\x93\xd1\x83\xd0\xb1\xd0\xba\xd0\xb8\xd0\xbd\xd0\xb0',
#  5417191: nan,
#  6093731: nan,
#  6388013: '\xd0\x9d\xd0\x98\xd0\xa3 \xd0\x92\xd0\xa8\xd0\xad (\xd0\x93\xd0\xa3-\xd0\x92\xd0\xa8\xd0\xad)',
#
#  292338302: '\xd0\x9d\xd0\x98\xd0\xa3 \xd0\x92\xd0\xa8\xd0\xad (\xd0\x93\xd0\xa3-\xd0\x92\xd0\xa8\xd0\xad)',
#  354139402: nan,
#  404777238: '\xd0\x93\xd0\x9a\xd0\x90 \xd0\xb8\xd0\xbc. \xd0\x9c\xd0\xb0\xd0\xb9\xd0\xbc\xd0\xbe\xd0\xbd\xd0\xb8\xd0\xb4\xd0\xb0 (\xd0\x9c\xd0\x93\xd0\xa3\xd0\x94\xd0\xa2)'}

# %%
nx.draw_networkx(G)

# %%
#take all nodes with degree >= 20
G1 = G.copy()
for node in G1.nodes():
    if G1.degree(node) < 20:
        G1.remove_node(node)

# %%
nx.draw_networkx(G1)

# %% [markdown]
# We can clearly see here two main groups

# %%
nx.write_graphml(G, 'graph.graphml')

# %%
degrees_dictionary = nx.degree(G)
degrees = np.array(degrees_dictionary.values())

# show node degrees
plt.xlabel('Degree')
plt.ylabel('Number')
plt.hist(degrees, 100)
plt.show()

# %% [markdown]
# Not even close to power law

# %%
len(G.nodes())
# Out:
# 153

# %%
# The Graph is not connected, so we'll take the largest connectivity component
components = sorted(nx.connected_component_subgraphs(G),key=len,reverse=True)
nx.radius(components[0])
# Out:
# 4

# %%
nx.diameter(components[0])
# Out:
# 8

# %%
nx.clustering(G)
# Out:
# {16450: 0.0,
#  42727: 0.0,
#  50385: 0.55,
#  4411633: 0.6102941176470589,
#  4793267: 0.6818181818181818,
#  5417191: 0.4707692307692308,
#  6093731: 0.64,
#  6388013: 0.6666666666666666,
#  6537447: 1.0,
#  6633765: 0.5697478991596638,
#  6805396: 0.5882352941176471,
#  6862930: 0.0,
#  7048636: 0.0,
#  7083123: 0.6666666666666666,
#  7321434: 1.0,
#  7343298: 1.0,
#  7358127: 0.625,
#  7422772: 0.9560439560439561,
#  7623029: 1.0,
#  8038711: 1.0,
#  8545045: 0.6322751322751323,
#  8900083: 1.0,
#  8920879: 0.7192982456140351,
#  8954930: 0.5052854122621564,
#  8964616: 0.0,
#  10105498: 0.7210144927536232,
#  10304893: 0.46554621848739497,
#  11397480: 0.5523809523809524,
#  11496815: 0.5504032258064516,
#  11776426: 0.5833333333333334,
#  12150421: 0.0,
#  12162034: 0.8888888888888888,
#  12228151: 0.6189516129032258,
#  12260423: 0.6738461538461539,
#  12330034: 0.5704099821746881,
#  12349850: 0.23809523809523808,
#  12395691: 0.5005807200929152,
#  12848273: 0.6633333333333333,
#  12904533: 0.5564102564102564,
#  13038891: 0.8,
#  13231153: 0.7908496732026143,
#  13338368: 0.5609195402298851,
#  13364721: 0.8676470588235294,
#  13466171: 0.5020242914979757,
#  13586747: 0.4166666666666667,
#  13665240: 0.5502645502645502,
#  140680040: 0.6345811051693404,
#  145708429: 0.5274725274725275,
#  146108531: 0.5814393939393939,
#  152122717: 0.6011396011396012,
#  157188286: 0.5161290322580645,
#  166445045: 0.0,
#  178760847: 0.8014705882352942,
#  182794807: 0.0,
#  183614829: 0.6,
#  215563351: 0.4708603145235893,
#  219696400: 0.68,
#  292338302: 0.5,
#  354139402: 0.0,
#  404777238: 0.7573529411764706}

# %%
#Quick snapshot of the Network
print nx.info(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 153
# Number of edges: 1401
# Average degree:  18.3137

# %%
#Create network layout for visualizations
spring_pos = nx.spring_layout(G)

# %%
plt.axis("off")
nx.draw_networkx(G, pos = spring_pos, with_labels = False, node_size = 55)

# %%
nx.draw_networkx(G1, pos = nx.spring_layout(G1), with_labels = False, node_size = 55)

# %%
from multiprocessing import Pool
2
import itertools

# %%
def partitions(nodes, n):
    nodes_iter = iter(nodes)
    while True:
        partition = tuple(itertools.islice(nodes_iter,n))
        if not partition:
            return
        yield partition

# To begin the parallel computation, we initialize a Pool object with the

# number of available processors on our hardware. We then partition the

# network based on the size of the Pool object (the size is equal to the

# number of available processors).

def between_parallel(G, processes = None):
    p = Pool(processes=processes)
    part_generator = 4*len(p._pool)
    node_partitions = list(partitions(G.nodes(), int(len(G)/part_generator)))
    num_partitions = len(node_partitions)
    #Next, we pass each processor a copy of the entire network and
    #compute the betweenness centrality for each vertex assigned to the
    #processor.
    bet_map = p.map(btwn_pool,
                    zip([G]*num_partitions,
                        [True]*num_partitions,
                        [None]*num_partitions,
                        node_partitions))
    #Finally, we collect the betweenness centrality calculations from each
    #pool and aggregate them together to compute the overall betweenness
    #centrality score for each vertex in the network.
    bt_c = bet_map[0]
    for bt in bet_map[1:]:
        for n in bt:
            bt_c[n] += bt[n]
    return bt_c

# %%
def btwn_pool(G_tuple):
    return nx.betweenness_centrality_source(*G_tuple)

# %%
def between_parallel(G, processes = None):
    p = Pool(processes=processes)
    part_generator = 4*len(p._pool)
    node_partitions = list(partitions(G.nodes(), int(len(G)/part_generator)))
    num_partitions = len(node_partitions)
 
    bet_map = p.map(btwn_pool,
                        zip([G]*num_partitions,
                        [True]*num_partitions,
                        [None]*num_partitions,
                        node_partitions))
 
    bt_c = bet_map[0]
    for bt in bet_map[1:]:
        for n in bt:
            bt_c[n] += bt[n]
    return bt_c

# %% [markdown]
# Betweenness Centrality

# %%
bt = between_parallel(G)
top = 10
max_nodes =  sorted(bt.iteritems(), key = lambda v: -v[1])[:top]
bt_values = [15]*len(G.nodes())
bt_colors = [0]*len(G.nodes())
for max_key, max_val in max_nodes:
    index = G.nodes().index(max_key)
    bt_values[index] = 150
    bt_colors[index] = 2
 
plt.axis("off")
nx.draw_networkx(G, pos = spring_pos, cmap = plt.get_cmap("rainbow"), node_color = bt_colors, node_size = bt_values, with_labels = False)

# %%
# top 10 betweenness centrality nodes
for max_key, max_val in max_nodes:
    print(names[max_key])
# Out:
# Valeria Khazova
# Alexandra Popova
# Nikolay Kuznetsov
# Alexander Zazulin
# Anton Scherbakov
# Andrey Isachenko
# Alexander Korzhakov
# Olga Binyavskaya
# Vika Akhromkina
# Pasha Babanov

# %% [markdown]
# Closeness Centrality + top 10 nodes

# %%
ct = nx.closeness_centrality(G)
top = 10
max_nodes1 =  sorted(ct.iteritems(), key = lambda v: -v[1])[:top]
ct_values = [15]*len(G.nodes())
ct_colors = [0]*len(G.nodes())
for max_key, max_val in max_nodes1:
    index = G.nodes().index(max_key)
    ct_values[index] = 150
    ct_colors[index] = 2
 
plt.axis("off")
nx.draw_networkx(G, pos = spring_pos, cmap = plt.get_cmap("rainbow"), node_color = ct_colors, node_size = ct_values, with_labels = False)

# %%
for max_key, max_val in max_nodes1:
    print(names[max_key])
# Out:
# Valeria Khazova
# Alexandra Popova
# Olga Binyavskaya
# Alexander Zazulin
# Alexey Antonchenko
# Anastasia Zubkova
# Alexey Volkov
# Pasha Babanov
# Vika Akhromkina
# Anton Scherbakov

# %% [markdown]
# Degree centrality + top 10 nodes

# %%
dt = nx.degree_centrality(G)
top = 10
max_nodes2 =  sorted(dt.iteritems(), key = lambda v: -v[1])[:top]
dt_values = [15]*len(G.nodes())
dt_colors = [0]*len(G.nodes())
for max_key, max_val in max_nodes2:
    index = G.nodes().index(max_key)
    dt_values[index] = 150
    dt_colors[index] = 2
 
plt.axis("off")
nx.draw_networkx(G, pos = spring_pos, cmap = plt.get_cmap("rainbow"), node_color = dt_colors, node_size = dt_values, with_labels = False)

# %%
for max_key, max_val in max_nodes2:
    print(names[max_key])
# Out:
# Yulia Kuznetsova
# Olga Binyavskaya
# Valeria Khazova
# Pasha Babanov
# Vika Akhromkina
# Sergey Ipatov
# Lyubov Korzh
# Olesya Tinkova
# Nikita Krikun
# Alexey Volkov

# %%
pr = sorted(nx.pagerank(G).items(), key=lambda x: x[1], reverse=True)

# %%
pr = nx.pagerank(G)
top = 10
max_nodes3 =  sorted(pr.iteritems(), key = lambda v: -v[1])[:top]
pr_values = [15]*len(G.nodes())
pr_colors = [0]*len(G.nodes())
for max_key, max_val in max_nodes3:
    index = G.nodes().index(max_key)
    pr_values[index] = 150
    pr_colors[index] = 2
 
plt.axis("off")
nx.draw_networkx(G, pos = spring_pos, cmap = plt.get_cmap("rainbow"), node_color = pr_colors, node_size = pr_values, with_labels = False)

# %%
for max_key, max_val in max_nodes3:
    print(names[max_key])
# Out:
# Olga Binyavskaya
# Valeria Khazova
# Yulia Kuznetsova
# Sergey Ipatov
# Vika Akhromkina
# Pasha Babanov
# Alexey Volkov
# Anastasia Zubkova
# Lyubov Korzh
# Danil Rakshas

# %%
import igraph as ig
from community import community_louvain
g = ig.Graph.TupleList(G.edges(), directed=True)

# %%
parts = community_louvain.best_partition(G)
values = [parts.get(node) for node in G.nodes()]

# %%
nx.draw_networkx(G, pos = spring_pos, cmap = plt.get_cmap("jet"), node_color = values, node_size = 35, with_labels = False)
